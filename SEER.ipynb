# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("C:/Users/Avika Malik/OneDrive/Documents/export.csv")

# Basic inspection
print(df.shape)              # rows, columns
print(df.columns)  # all column names
print(df.head())             # first 5 rows
print(df.dtypes)             # data types
print(df.info())             #all info
# Out:
# (1048575, 12)
# Index(['Age recode with <1 year olds and 90+', 'Sex', 'Year of diagnosis',
#        'Site recode ICD-O-3/WHO 2008', 'Grade Clinical (2018+)',
#        'Histology recode - broad groupings', 'Primary Site - labeled',
#        'Combined Summary Stage with Expanded Regional Codes (2004+)',
#        'Tumor Size Summary (2016+)', 'Vital status recode (study cutoff used)',
#        'Survival months',
#        'COD to site recode ICD-O-3 2023 Revision Expanded (1999+)'],
#       dtype='object')
#   Age recode with <1 year olds and 90+     Sex  Year of diagnosis  \
# 0                          40-44 years    Male               2002
# 1                          65-69 years    Male               2000
# 2                          35-39 years  Female               2008
# 3                          60-64 years  Female               2008
# 4                            90+ years    Male               2008
#
#                         Site recode ICD-O-3/WHO 2008 Grade Clinical (2018+)  \
# 0                                             Testis               Blank(s)
# 1                                             Rectum               Blank(s)
# 2                              Rectosigmoid Junction               Blank(s)
# 3  Trachea, Mediastinum and Other Respiratory Organs               Blank(s)
# 4                               Melanoma of the Skin               Blank(s)
#
#                 Histology recode - broad groupings  \
# 0                   9060-9099: germ cell neoplasms
# 1          8140-8389: adenomas and adenocarcinomas
# 2          8140-8389: adenomas and adenocarcinomas
# 3  8800-8809: soft tissue tumors and sarcomas, NOS
# 4                    8720-8799: nevi and melanomas
#
#          Primary Site - labeled  \
# 0             C62.9-Testis, NOS
# 1             C20.9-Rectum, NOS
# 2   C19.9-Rectosigmoid junction
# 3    C38.1-Anterior mediastinum
# 4  C44.4-Skin of scalp and neck
#
#   Combined Summary Stage with Expanded Regional Codes (2004+)  \
# 0                                           Blank(s)
# 1                                           Blank(s)
# 2                   Distant site(s)/node(s) involved
# 3                                     Localized only
# 4                                     Localized only
#
#   Tumor Size Summary (2016+) Vital status recode (study cutoff used)  \
# 0                   Blank(s)                                   Alive
# 1                   Blank(s)                                    Dead
# 2                   Blank(s)                                   Alive
# 3                   Blank(s)                                    Dead
# 4                   Blank(s)                                    Dead
#
#   Survival months COD to site recode ICD-O-3 2023 Revision Expanded (1999+)
# 0             244                                              Alive
# 1              49              Colon And Rectum (Excluding Appendix)
# 2             179                                              Alive
# 3               0                      Heart, Mediastinum And Pleura
# 4              26                                          Other COD
# Age recode with <1 year olds and 90+                           object
# Sex                                                            object
# Year of diagnosis                                               int64
# Site recode ICD-O-3/WHO 2008                                   object
# Grade Clinical (2018+)                                         object
# Histology recode - broad groupings                             object
# Primary Site - labeled                                         object
# Combined Summary Stage with Expanded Regional Codes (2004+)    object
# Tumor Size Summary (2016+)                                     object
# Vital status recode (study cutoff used)                        object
# Survival months                                                object
# COD to site recode ICD-O-3 2023 Revision Expanded (1999+)      object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 12 columns):
#  #   Column                                                       Non-Null Count    Dtype
# ---  ------                                                       --------------    -----
#  0   Age recode with <1 year olds and 90+                         1048575 non-null  object
#  1   Sex                                                          1048575 non-null  object
#  2   Year of diagnosis                                            1048575 non-null  int64
#  3   Site recode ICD-O-3/WHO 2008                                 1048575 non-null  object
#  4   Grade Clinical (2018+)                                       1048575 non-null  object
#  5   Histology recode - broad groupings                           1048575 non-null  object
#  6   Primary Site - labeled                                       1048575 non-null  object
#  7   Combined Summary Stage with Expanded Regional Codes (2004+)  1048575 non-null  object
#  8   Tumor Size Summary (2016+)                                   1048575 non-null  object
#  9   Vital status recode (study cutoff used)                      1048575 non-null  object
#  10  Survival months                                              1048575 non-null  object
#  11  COD to site recode ICD-O-3 2023 Revision Expanded (1999+)    1048575 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 96.0+ MB
# None

# %%
df.rename(columns={
    'Age recode with <1 year olds and 90+' : 'Age',
    'Sex'                                   : 'Sex',
    'Year of diagnosis'                     : 'Year_Diagnosis',
    'Site recode ICD-O-3/WHO 2008'          : 'Site_Recode',
    'Grade Clinical (2018+)'                : 'Grade',
    'Histology recode - broad groupings'    : 'Histology',
    'Primary Site - labeled'               : 'Primary_Site',
    'Combined Summary Stage with Expanded Regional Codes (2004+)'               : 'Stage',
    'Tumor Size Summary (2016+)'           : 'Tumor_Size',
    'Vital status recode (study cutoff used)': 'Vital_Status',
    'Survival months'                      : 'Survival_Months',
    'COD to site recode ICD-O-3 2023 Revision Expanded (1999+)': 'Cause_of_Death'
}, inplace=True)

print(df.columns.tolist())
df
# Out:
# ['Age', 'Sex', 'Year_Diagnosis', 'Site_Recode', 'Grade', 'Histology', 'Primary_Site', 'Stage', 'Tumor_Size', 'Vital_Status', 'Survival_Months', 'Cause_of_Death']
#                  Age     Sex  Year_Diagnosis  \
# 0        40-44 years    Male            2002
# 1        65-69 years    Male            2000
# 2        35-39 years  Female            2008
# 3        60-64 years  Female            2008
# 4          90+ years    Male            2008
# ...              ...     ...             ...
# 1048570  50-54 years  Female            2011
# 1048571  45-49 years  Female            2011
# 1048572  60-64 years  Female            2011
# 1048573  75-79 years  Female            2011
# 1048574  35-39 years  Female            2011
#
#                                                Site_Recode     Grade  \
# 0                                                   Testis  Blank(s)
# 1                                                   Rectum  Blank(s)
# 2                                    Rectosigmoid Junction  Blank(s)
# 3        Trachea, Mediastinum and Other Respiratory Organs  Blank(s)
# 4                                     Melanoma of the Skin  Blank(s)
# ...                                                    ...       ...
# 1048570                                             Breast  Blank(s)
# 1048571                                             Breast  Blank(s)
# 1048572                                             Breast  Blank(s)
# 1048573                                             Breast  Blank(s)
# 1048574                                             Breast  Blank(s)
#
#                                                Histology  \
# 0                         9060-9099: germ cell neoplasms
# 1                8140-8389: adenomas and adenocarcinomas
# 2                8140-8389: adenomas and adenocarcinomas
# 3        8800-8809: soft tissue tumors and sarcomas, NOS
# 4                          8720-8799: nevi and melanomas
# ...                                                  ...
# 1048570          8500-8549: ductal and lobular neoplasms
# 1048571          8140-8389: adenomas and adenocarcinomas
# 1048572          8500-8549: ductal and lobular neoplasms
# 1048573          8500-8549: ductal and lobular neoplasms
# 1048574          8500-8549: ductal and lobular neoplasms
#
#                                  Primary_Site  \
# 0                           C62.9-Testis, NOS
# 1                           C20.9-Rectum, NOS
# 2                 C19.9-Rectosigmoid junction
# 3                  C38.1-Anterior mediastinum
# 4                C44.4-Skin of scalp and neck
# ...                                       ...
# 1048570  C50.5-Lower-outer quadrant of breast
# 1048571  C50.5-Lower-outer quadrant of breast
# 1048572  C50.4-Upper-outer quadrant of breast
# 1048573  C50.4-Upper-outer quadrant of breast
# 1048574  C50.5-Lower-outer quadrant of breast
#
#                                       Stage Tumor_Size Vital_Status  \
# 0                                  Blank(s)   Blank(s)        Alive
# 1                                  Blank(s)   Blank(s)         Dead
# 2          Distant site(s)/node(s) involved   Blank(s)        Alive
# 3                            Localized only   Blank(s)         Dead
# 4                            Localized only   Blank(s)         Dead
# ...                                     ...        ...          ...
# 1048570  Regional lymph nodes involved only   Blank(s)        Alive
# 1048571                      Localized only   Blank(s)        Alive
# 1048572  Regional lymph nodes involved only   Blank(s)         Dead
# 1048573                      Localized only   Blank(s)        Alive
# 1048574                      Localized only   Blank(s)        Alive
#
#         Survival_Months                         Cause_of_Death
# 0                   244                                  Alive
# 1                    49  Colon And Rectum (Excluding Appendix)
# 2                   179                                  Alive
# 3                     0          Heart, Mediastinum And Pleura
# 4                    26                              Other COD
# ...                 ...                                    ...
# 1048570              71                                  Alive
# 1048571             143                                  Alive
# 1048572               8                              Other COD
# 1048573             106                                  Alive
# 1048574             142                                  Alive
#
# [1048575 rows x 12 columns]

# %%
unknown_values = ['Blank(s)', 'Unknown', 'unknown', 
                   'Not applicable', '99', '999', 'NA']
df.replace(unknown_values, np.nan, inplace=True)
df
# Out:
#                  Age     Sex  Year_Diagnosis  \
# 0        40-44 years    Male            2002
# 1        65-69 years    Male            2000
# 2        35-39 years  Female            2008
# 3        60-64 years  Female            2008
# 4          90+ years    Male            2008
# ...              ...     ...             ...
# 1048570  50-54 years  Female            2011
# 1048571  45-49 years  Female            2011
# 1048572  60-64 years  Female            2011
# 1048573  75-79 years  Female            2011
# 1048574  35-39 years  Female            2011
#
#                                                Site_Recode Grade  \
# 0                                                   Testis   NaN
# 1                                                   Rectum   NaN
# 2                                    Rectosigmoid Junction   NaN
# 3        Trachea, Mediastinum and Other Respiratory Organs   NaN
# 4                                     Melanoma of the Skin   NaN
# ...                                                    ...   ...
# 1048570                                             Breast   NaN
# 1048571                                             Breast   NaN
# 1048572                                             Breast   NaN
# 1048573                                             Breast   NaN
# 1048574                                             Breast   NaN
#
#                                                Histology  \
# 0                         9060-9099: germ cell neoplasms
# 1                8140-8389: adenomas and adenocarcinomas
# 2                8140-8389: adenomas and adenocarcinomas
# 3        8800-8809: soft tissue tumors and sarcomas, NOS
# 4                          8720-8799: nevi and melanomas
# ...                                                  ...
# 1048570          8500-8549: ductal and lobular neoplasms
# 1048571          8140-8389: adenomas and adenocarcinomas
# 1048572          8500-8549: ductal and lobular neoplasms
# 1048573          8500-8549: ductal and lobular neoplasms
# 1048574          8500-8549: ductal and lobular neoplasms
#
#                                  Primary_Site  \
# 0                           C62.9-Testis, NOS
# 1                           C20.9-Rectum, NOS
# 2                 C19.9-Rectosigmoid junction
# 3                  C38.1-Anterior mediastinum
# 4                C44.4-Skin of scalp and neck
# ...                                       ...
# 1048570  C50.5-Lower-outer quadrant of breast
# 1048571  C50.5-Lower-outer quadrant of breast
# 1048572  C50.4-Upper-outer quadrant of breast
# 1048573  C50.4-Upper-outer quadrant of breast
# 1048574  C50.5-Lower-outer quadrant of breast
#
#                                       Stage Tumor_Size Vital_Status  \
# 0                                       NaN        NaN        Alive
# 1                                       NaN        NaN         Dead
# 2          Distant site(s)/node(s) involved        NaN        Alive
# 3                            Localized only        NaN         Dead
# 4                            Localized only        NaN         Dead
# ...                                     ...        ...          ...
# 1048570  Regional lymph nodes involved only        NaN        Alive
# 1048571                      Localized only        NaN        Alive
# 1048572  Regional lymph nodes involved only        NaN         Dead
# 1048573                      Localized only        NaN        Alive
# 1048574                      Localized only        NaN        Alive
#
#         Survival_Months                         Cause_of_Death
# 0                   244                                  Alive
# 1                    49  Colon And Rectum (Excluding Appendix)
# 2                   179                                  Alive
# 3                     0          Heart, Mediastinum And Pleura
# 4                    26                              Other COD
# ...                 ...                                    ...
# 1048570              71                                  Alive
# 1048571             143                                  Alive
# 1048572               8                              Other COD
# 1048573             106                                  Alive
# 1048574             142                                  Alive
#
# [1048575 rows x 12 columns]

# %%
missing_count = df.isnull().sum()
total_rows=len(df)
missing_perct= (missing_count/total_rows *100).round(2)
missing_df = pd.DataFrame({
    'Missing Count' : missing_count,'Missing %' : missing_perct})
print(missing_df[missing_df['Missing Count'] > 0])
# Out:
#                  Missing Count  Missing %
# Grade                   816613      77.88
# Stage                   175965      16.78
# Tumor_Size              851046      81.16
# Survival_Months          15104       1.44

# %%
cols_to_fix=['Grade','Tumor_Size','Stage','Survival_Months']
df.dropna(subset=cols_to_fix,inplace=True)
df.reset_index(drop=True,inplace=True)
print(df.columns)
print(df.shape)
df
# Out:
# Index(['Age', 'Sex', 'Year_Diagnosis', 'Site_Recode', 'Grade', 'Histology',
#        'Primary_Site', 'Stage', 'Tumor_Size', 'Vital_Status',
#        'Survival_Months', 'Cause_of_Death'],
#       dtype='object')
# (141223, 12)
#                 Age     Sex  Year_Diagnosis        Site_Recode Grade  \
# 0       70-74 years  Female            2018             Breast     9
# 1       60-64 years  Female            2019       Corpus Uteri     9
# 2       65-69 years    Male            2018  Lung and Bronchus     2
# 3       75-79 years  Female            2021           Pancreas     9
# 4       65-69 years  Female            2022            Stomach     9
# ...             ...     ...             ...                ...   ...
# 141218  40-44 years  Female            2019             Breast     3
# 141219  80-84 years  Female            2018  Lung and Bronchus     9
# 141220  70-74 years  Female            2021    Small Intestine     9
# 141221  65-69 years  Female            2020  Lung and Bronchus     9
# 141222  75-79 years  Female            2021             Breast     1
#
#                                              Histology  \
# 0              8500-8549: ductal and lobular neoplasms
# 1              8140-8389: adenomas and adenocarcinomas
# 2              8140-8389: adenomas and adenocarcinomas
# 3              8500-8549: ductal and lobular neoplasms
# 4       8930-8999: complex mixed and stromal neoplasms
# ...                                                ...
# 141218         8500-8549: ductal and lobular neoplasms
# 141219         8140-8389: adenomas and adenocarcinomas
# 141220  8930-8999: complex mixed and stromal neoplasms
# 141221         8140-8389: adenomas and adenocarcinomas
# 141222         8500-8549: ductal and lobular neoplasms
#
#                                 Primary_Site  \
# 0         C50.8-Overlapping lesion of breast
# 1                          C54.1-Endometrium
# 2                     C34.1-Upper lobe, lung
# 3                     C25.0-Head of pancreas
# 4                       C16.3-Gastric antrum
# ...                                      ...
# 141218  C50.2-Upper-inner quadrant of breast
# 141219                C34.1-Upper lobe, lung
# 141220                         C17.1-Jejunum
# 141221                C34.1-Upper lobe, lung
# 141222    C50.8-Overlapping lesion of breast
#
#                                                     Stage Tumor_Size  \
# 0                                          Localized only         24
# 1                                          Localized only          1
# 2       Regional by both direct extension and lymph no...         70
# 3       Regional by both direct extension and lymph no...         28
# 4                                          Localized only         28
# ...                                                   ...        ...
# 141218                                     Localized only         12
# 141219                                     Localized only         36
# 141220                                     Localized only         23
# 141221                   Distant site(s)/node(s) involved         24
# 141222                                     Localized only         10
#
#        Vital_Status Survival_Months     Cause_of_Death
# 0             Alive              59              Alive
# 1             Alive              39              Alive
# 2             Alive              59              Alive
# 3             Alive              15              Alive
# 4             Alive               7              Alive
# ...             ...             ...                ...
# 141218        Alive              41              Alive
# 141219         Dead              34  Lung And Bronchus
# 141220        Alive              18              Alive
# 141221        Alive              28              Alive
# 141222        Alive              18              Alive
#
# [141223 rows x 12 columns]

# %%
cols=['Grade','Tumor_Size','Survival_Months']
for col in cols:
    df[col]=pd.to_numeric(df[col],errors='coerce')
    df[col]=df[col].fillna(0).astype(int)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 141223 entries, 134684 to 24926
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Age              141223 non-null  object
#  1   Sex              141223 non-null  object
#  2   Year_Diagnosis   141223 non-null  int64
#  3   Site_Recode      141223 non-null  object
#  4   Grade            141223 non-null  int64
#  5   Histology        141223 non-null  object
#  6   Primary_Site     141223 non-null  object
#  7   Stage            141223 non-null  object
#  8   Tumor_Size       141223 non-null  int64
#  9   Vital_Status     141223 non-null  object
#  10  Survival_Months  141223 non-null  int64
#  11  Cause_of_Death   141223 non-null  object
#  12  Age_Numeric      141223 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 15.1+ MB
# None

# %%
df.groupby(['Age', 'Sex']).size().unstack().plot(
    kind='bar',
    figsize=(15, 6),
    color=['#f4a582', '#92c5de']  # pink for Female, blue for Male
)

plt.title('Cancer Case Distribution by Age and Sex', fontsize=14)
plt.xlabel('Age Group')
plt.ylabel('Number of Cases')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Sex')
plt.tight_layout()
plt.show()

# %%
# 1. Convert categorical Age (e.g., '40-44') to a number (takes the first number)
# This is necessary because boxplots require numerical values for the Y-axis.
df['Age_Numeric'] = df['Age'].str.extract('(\d+)').astype(float)

# 2. Create the Box Plot
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Vital_Status', y='Age_Numeric',hue='Vital_Status', palette='Set2')

# 3. Add labels
plt.title('Age Distribution by Vital Status')
plt.xlabel('Vital Status')
plt.ylabel('Age (Years)')

plt.show()

# %%
# 1. Count the occurrences of each status
status_counts = df['Vital_Status'].value_counts()

# 2. Create the Pie Chart
plt.figure(figsize=(5, 5))
plt.pie(status_counts, 
        labels=status_counts.index, 
        autopct='%1.1f%%', 
        colors=['#007fff','#00bfff'], 
        startangle=140)

plt.title('Percentage of Patients: Alive vs. Deceased')
plt.show()

# %%
site_counts=df['Primary_Site'].value_counts()
print(site_counts)
top_10_sites=site_counts.head(10).index
print(top_10_sites)
df_top_10=df[df['Primary_Site'].isin(top_10_sites)]
df_top_10
# Out:
# Primary_Site
# C50.4-Upper-outer quadrant of breast                  12847
# C34.1-Upper lobe, lung                                11399
# C50.8-Overlapping lesion of breast                     9134
# C61.9-Prostate gland                                   6696
# C64.9-Kidney, NOS                                      6690
#                                                       ...
# C63.7-Other specified parts of male genital organs        1
# C21.2-Cloacogenic zone                                    1
# C70.1-Spinal meninges                                     1
# C72.5-Cranial nerve, NOS                                  1
# C26.0-Intestinal tract, NOS                               1
# Name: count, Length: 295, dtype: int64
# Index(['C50.4-Upper-outer quadrant of breast', 'C34.1-Upper lobe, lung',
#        'C50.8-Overlapping lesion of breast', 'C61.9-Prostate gland',
#        'C64.9-Kidney, NOS', 'C34.3-Lower lobe, lung', 'C73.9-Thyroid gland',
#        'C54.1-Endometrium', 'C50.2-Upper-inner quadrant of breast',
#        'C20.9-Rectum, NOS'],
#       dtype='object', name='Primary_Site')
#                 Age     Sex  Year_Diagnosis        Site_Recode  Grade  \
# 68880   50-54 years  Female            2022             Breast      2
# 103664    90+ years    Male            2019  Lung and Bronchus      3
# 103457  80-84 years  Female            2019  Lung and Bronchus      9
# 103223  55-59 years  Female            2019            Thyroid      9
# 29338   85-89 years    Male            2019  Lung and Bronchus      9
# ...             ...     ...             ...                ...    ...
# 60511   40-44 years  Female            2022             Breast      0
# 60515   60-64 years  Female            2022             Breast      0
# 120881  60-64 years  Female            2021  Lung and Bronchus      9
# 120882  70-74 years  Female            2021       Corpus Uteri      3
# 60442   75-79 years    Male            2021  Lung and Bronchus      9
#
#                                       Histology  \
# 68880   8500-8549: ductal and lobular neoplasms
# 103664     8010-8049: epithelial neoplasms, NOS
# 103457         8000-8009: unspecified neoplasms
# 103223  8140-8389: adenomas and adenocarcinomas
# 29338        8050-8089: squamous cell neoplasms
# ...                                         ...
# 60511   8500-8549: ductal and lobular neoplasms
# 60515   8500-8549: ductal and lobular neoplasms
# 120881  8140-8389: adenomas and adenocarcinomas
# 120882  8140-8389: adenomas and adenocarcinomas
# 60442      8010-8049: epithelial neoplasms, NOS
#
#                                 Primary_Site  \
# 68880   C50.4-Upper-outer quadrant of breast
# 103664                C34.1-Upper lobe, lung
# 103457                C34.1-Upper lobe, lung
# 103223                   C73.9-Thyroid gland
# 29338                 C34.1-Upper lobe, lung
# ...                                      ...
# 60511   C50.2-Upper-inner quadrant of breast
# 60515   C50.4-Upper-outer quadrant of breast
# 120881                C34.3-Lower lobe, lung
# 120882                     C54.1-Endometrium
# 60442                 C34.1-Upper lobe, lung
#
#                                      Stage  Tumor_Size Vital_Status  \
# 68880   Regional lymph nodes involved only          25        Alive
# 103664    Distant site(s)/node(s) involved          14         Dead
# 103457    Distant site(s)/node(s) involved          11         Dead
# 103223                      Localized only          13        Alive
# 29338     Distant site(s)/node(s) involved          20         Dead
# ...                                    ...         ...          ...
# 60511                       Localized only          19        Alive
# 60515                       Localized only          10        Alive
# 120881                      Localized only          10        Alive
# 120882    Distant site(s)/node(s) involved         128         Dead
# 60442     Distant site(s)/node(s) involved          29         Dead
#
#         Survival_Months                                     Cause_of_Death  \
# 68880                 0                                              Alive
# 103664                0                                  Lung And Bronchus
# 103457                0                                  Lung And Bronchus
# 103223                0                                              Alive
# 29338                 0                                  Lung And Bronchus
# ...                 ...                                                ...
# 60511                 9                                              Alive
# 60515                 9                                              Alive
# 120881                9                                              Alive
# 120882                9                                             Corpus
# 60442                 9  State DC not available or state DC available b...
#
#         Age_Numeric
# 68880          50.0
# 103664         90.0
# 103457         80.0
# 103223         55.0
# 29338          85.0
# ...             ...
# 60511          40.0
# 60515          60.0
# 120881         60.0
# 120882         70.0
# 60442          75.0
#
# [72625 rows x 13 columns]

# %%
plt.figure(figsize=(12, 8))
sns.countplot(
    data=df_top_10, 
    y='Primary_Site', 
    order=top_10_sites, 
    hue='Primary_Site', 
    palette='mako', 
    legend=False
)
plt.title('Top 10 Most Frequent Cancer Primary Sites', fontsize=14)
plt.xlabel('Total Number of Cases')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))

sns.histplot(data=df, x='Survival_Months', bins=40, kde=True, color='magenta')

plt.title('Distribution of Survival Months')
plt.xlabel('Months Since Diagnosis')
plt.ylabel('Number of Patients')
plt.xticks(rotation=90)
plt.show()

# %%
# 1. Select the numeric columns
cols = ['Age_Numeric', 'Tumor_Size', 'Survival_Months']

data_subset=df[cols]
print(data_subset.dtypes)
# 2. Get the Matrices
cor_matrix = data_subset.corr()
cov_matrix = data_subset.cov()
# 3. Print the results
print("Correlation Matrix:\n", cor_matrix)
print("\nCovariance Matrix:\n", cov_matrix)

# 4. Plot the Heatmap (Standard for reports)
plt.figure(figsize=(8, 6))
sns.heatmap(cor_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# Age_Numeric        float64
# Tumor_Size           int64
# Survival_Months      int64
# dtype: object
# Correlation Matrix:
#                   Age_Numeric  Tumor_Size  Survival_Months
# Age_Numeric         1.000000    0.003908        -0.148272
# Tumor_Size          0.003908    1.000000        -0.060837
# Survival_Months    -0.148272   -0.060837         1.000000
#
# Covariance Matrix:
#                   Age_Numeric   Tumor_Size  Survival_Months
# Age_Numeric       213.883778     4.321063       -37.844452
# Tumor_Size          4.321063  5716.405439       -80.275212
# Survival_Months   -37.844452   -80.275212       304.584997

# %%
stage_status = pd.crosstab(df['Stage'], 
                           df['Vital_Status'], 
                           normalize='index')

# 2. Plot as a horizontal stacked bar chart
stage_status.plot(kind='barh', 
                  stacked=True, 
                  color=['#2ecc71', '#e74c3c'], # Green for Alive, Red for Dead
                  figsize=(10, 6))

# 3. Add labels
plt.title('Percentage of Survivors vs. Deceased by Cancer Stage', fontsize=14)
plt.xlabel('Percentage (1.0 = 100%)')
plt.ylabel('Stage at Diagnosis')
plt.legend(title='Status', bbox_to_anchor=(1.05, 1))

plt.tight_layout()
plt.show()
#in situ- cancer is only in original location, hasn't spread at all
#localised only- confined to organ where starts
#by direct extension- spread to nearby tissue
#lymph nodes- spread to nearby lymph nodes
